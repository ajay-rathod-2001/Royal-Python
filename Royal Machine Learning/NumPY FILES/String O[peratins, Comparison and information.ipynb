# %% [markdown]
# String Operations, Comparison and information :

# %%
import numpy as np

# %%
str = " Proud of My Country, I always as an Indian"
str1 ="Learnig In Python NumPy For Machine Learning"

# %%
np.char.add(str, str1)
# Out:
# np.str_(' Proud of My Country, I always as an IndianLearnig In Python NumPy For Machine Learning')

# %%
np.char.lower(str)
# Out:
# array(' proud of my country, i always as an indian', dtype='<U43')

# %%
np.char.upper(str1)
# Out:
# array('LEARNIG IN PYTHON NUMPY FOR MACHINE LEARNING', dtype='<U44')

# %%
np.char.center(str1, 60)
# Out:
# array('        Learnig In Python NumPy For Machine Learning        ',
#       dtype='<U60')

# %%
np.char.center(str1, 60, fillchar="*")
# Out:
# array('********Learnig In Python NumPy For Machine Learning********',
#       dtype='<U60')

# %%
np.char.split(str)
# Out:
# array(list(['Proud', 'of', 'My', 'Country,', 'I', 'always', 'as', 'an', 'Indian']),
#       dtype=object)

# %%
np.char.splitlines("hello\nIndian")
# Out:
# array(list(['hello', 'Indian']), dtype=object)

# %%
str4= "dmy"
str5= "dmy"

# %%
np.char.join([":", "/"],[str4,str5])
# Out:
# array(['d:m:y', 'd/m/y'], dtype='<U5')

# %%
np.char.replace(str, "Proud", "Always Proud")
# Out:
# array(' Always Proud of My Country, I always as an Indian', dtype='<U50')

# %%
np.char.equal(str4, str5)
# Out:
# array(True)

# %%
np.char.count(str, "a")
# Out:
# np.int64(5)

# %%
str
# Out:
# ' Proud of My Country, I always as an Indian'

# %%
np.char.find(str, "Country")
# Out:
# np.int64(13)
