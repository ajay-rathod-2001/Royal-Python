# %% [markdown]
# Random Sampling With NumPy :

# %%
import numpy as np
import random

# %%
np.random.random(1)
# Out:
# array([0.72342923])

# %%
np.random.random((3,3))
# Out:
# array([[0.07102342, 0.95813196, 0.06178571],
#        [0.09412315, 0.33477702, 0.93561803],
#        [0.29209356, 0.28887288, 0.85396422]])

# %%
np.random.randint(1,4)
# Out:
# 2

# %%
np.random.randint(1,4, (4,4))
# Out:
# array([[2, 1, 1, 2],
#        [2, 3, 3, 3],
#        [2, 2, 2, 1],
#        [1, 1, 3, 2]], dtype=int32)

# %%
np.random.randint(1,4, (2,4,4))
# Out:
# array([[[2, 1, 2, 2],
#         [2, 3, 1, 1],
#         [1, 2, 2, 1],
#         [1, 3, 3, 3]],
#
#        [[3, 2, 1, 2],
#         [3, 2, 3, 1],
#         [1, 2, 2, 1],
#         [3, 2, 2, 3]]], dtype=int32)

# %%
np.random.seed(10)
np.random.randint(1,4, (2,4,4))
# Out:
# array([[[2, 2, 1, 1],
#         [2, 1, 2, 2],
#         [1, 2, 2, 3],
#         [1, 2, 1, 3]],
#
#        [[1, 3, 1, 1],
#         [1, 3, 1, 3],
#         [3, 2, 1, 1],
#         [3, 2, 3, 2]]], dtype=int32)

# %%
np.random.seed(10)
np.random.randint(1,4, (2,4,4))
# Out:
# array([[[2, 2, 1, 1],
#         [2, 1, 2, 2],
#         [1, 2, 2, 3],
#         [1, 2, 1, 3]],
#
#        [[1, 3, 1, 1],
#         [1, 3, 1, 3],
#         [3, 2, 1, 1],
#         [3, 2, 3, 2]]], dtype=int32)

# %%
2**32 -1
# Out:
# 4294967295

# %%
np.random.rand(3)
# Out:
# array([0.13145815, 0.41366737, 0.77872881])

# %%
np.random.rand(3,3)
# Out:
# array([[0.58390137, 0.18263144, 0.82608225],
#        [0.10540183, 0.28357668, 0.06556327],
#        [0.05644419, 0.76545582, 0.01178803]])

# %%
x = [1,2,3,4]
np.random.choice(x)
# Out:
# np.int64(4)

# %%
np.random.choice(x)
# Out:
# np.int64(1)

# %%
np.random.choice(x)
# Out:
# np.int64(3)

# %%
for i in range(20):
   print( np.random.choice(x))
# Out:
# 2
# 1
# 4
# 1
# 1
# 3
# 1
# 3
# 3
# 1
# 4
# 2
# 1
# 4
# 2
# 3
# 3
# 2
# 3
# 3

# %%
x
# Out:
# [1, 2, 3, 4]

# %%
np.random.permutation(x)
# Out:
# array([2, 3, 1, 4])

# %%
np.random.permutation(x)
# Out:
# array([2, 3, 4, 1])
