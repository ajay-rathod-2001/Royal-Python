# %% [markdown]
# ## Missing Value Imputation - Categorical Variable

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\ajayr\Downloads\train.csv")

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
cat_vars = df.select_dtypes(include='str')
cat_vars.head()
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
# 3       RL   Pave   NaN      IR1         Lvl    AllPub    Corner       Gtl
# 4       RL   Pave   NaN      IR1         Lvl    AllPub       FR2       Gtl
#
#   Neighborhood Condition1  ... GarageType GarageFinish GarageQual GarageCond  \
# 0      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 1      Veenker      Feedr  ...     Attchd          RFn         TA         TA
# 2      CollgCr       Norm  ...     Attchd          RFn         TA         TA
# 3      Crawfor       Norm  ...     Detchd          Unf         TA         TA
# 4      NoRidge       Norm  ...     Attchd          RFn         TA         TA
#
# ...

# %%
miss_val_per = cat_vars.isnull().mean()*100
miss_val_per
# Out:
# MSZoning          0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinType2      2.602740
# Heating           0.000000
# HeatingQC         0.000000
# CentralAir        0.000000
# Electrical        0.068493
# KitchenQual       0.000000
# Functional        0.000000
# FireplaceQu      47.260274
# GarageType        5.547945
# ...

# %%
drop_vars = ['Alley','FireplaceQu','PoolQC','Fence','MiscFeature']
cat_vars.drop(drop_vars, axis=1, inplace=True)
cat_vars.shape
# Out:
# (1460, 38)

# %%
isnull_per = cat_vars.isnull().mean()*100
miss_vars = isnull_per[isnull_per > 0].keys()
miss_vars
# Out:
# Index(['MasVnrType', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Electrical', 'GarageType', 'GarageFinish',
#        'GarageQual', 'GarageCond'],
#       dtype='str')

# %%
# Imputes The missing Values - method used
cat_vars['MasVnrType'].fillna("Missing")
# Out:
# 0       BrkFace
# 1       Missing
# 2       BrkFace
# 3       Missing
# 4       BrkFace
#          ...
# 1455    Missing
# 1456      Stone
# 1457    Missing
# 1458    Missing
# 1459    Missing
# Name: MasVnrType, Length: 1460, dtype: str

# %%
# Add Mode Values - Method used
cat_vars['MasVnrType'].mode()
# Out:
# 0    BrkFace
# Name: MasVnrType, dtype: str

# %%
# count the Values - method used
cat_vars['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
# Filling Missing values - method use
cat_vars['MasVnrType'].fillna(cat_vars['MasVnrType'].mode()[0], inplace=True)
# Out:
# C:\Users\ajayr\AppData\Local\Temp\ipykernel_23080\1705962022.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   cat_vars['MasVnrType'].fillna(cat_vars['MasVnrType'].mode()[0], inplace=True)
# 0       BrkFace
# 1       BrkFace
# 2       BrkFace
# 3       BrkFace
# 4       BrkFace
#          ...
# 1455    BrkFace
# ...

# %%
# Number of feature Imputation code-methos used
for var in miss_vars:
    cat_vars[var].fillna(cat_vars[var].mode()[0], inplace=True)
    print(var, "=", cat_vars[var].mode()[0])
# Out:
# MasVnrType = BrkFace
# BsmtQual = TA
# BsmtCond = TA
# BsmtExposure = No
# BsmtFinType1 = Unf
# BsmtFinType2 = Unf
# Electrical = SBrkr
# GarageType = Attchd
# GarageFinish = Unf
# GarageQual = TA
# GarageCond = TA
# C:\Users\ajayr\AppData\Local\Temp\ipykernel_23080\3531302909.py:3: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# ...

# %%
# ckeck the null value inpute or not
cat_vars.isnull().sum()
# Out:
# MSZoning           0
# Street             0
# LotShape           0
# LandContour        0
# Utilities          0
# LotConfig          0
# LandSlope          0
# Neighborhood       0
# Condition1         0
# Condition2         0
# BldgType           0
# HouseStyle         0
# RoofStyle          0
# RoofMatl           0
# Exterior1st        0
# Exterior2nd        0
# MasVnrType       872
# ExterQual          0
# ExterCond          0
# Foundation         0
# BsmtQual          37
# BsmtCond          37
# BsmtExposure      38
# BsmtFinType1      37
# BsmtFinType2      38
# Heating            0
# HeatingQC          0
# CentralAir         0
# Electrical         1
# KitchenQual        0
# Functional         0
# GarageType        81
# GarageFinish      81
# GarageQual        81
# GarageCond        81
# PavedDrive         0
# SaleType           0
# SaleCondition      0
# dtype: int64

# %%
# Data Distribution - method use
plt.figure(figsize=(16,9))
for i, var in enumerate(miss_vars):
    plt.subplot(4,3,i+1)
    plt.hist(cat_vars[var].dropna(), label="Imput")
    plt.hist(df[var].dropna(), label="Original")
    plt.title(var)
    plt.legend
    plt.tight_layout()
