# %% [markdown]
# ## Pandas DatetimeIndex Functionality :

# %%
import pandas as pd

# %%
df =pd.read_csv("C:\\Users\\ajayr\\OneDrive\\Documents\\Friends Name.csv", parse_dates =['Date'])
df
# Out:
#     SR        Date              Nmes            Trades  Hours  Marks
# 0    1  02-03-2026       Ajay Rathod               CSE    2.5   21.0
# 1    2  03-03-2026       Vijay Agose                BA    5.1   47.0
# 2    3  04-03-2026       Amol Jadhav        Mechanical    3.2   27.0
# 3    4  05-03-2026      Surya Mekale        Electrical    8.5   75.0
# 4    5  06-03-2026       Lakhan More               CSE    3.5   30.0
# 5    6  07-03-2026       Suyog Mohod               CSE    NaN   20.0
# 6    7  08-03-2026    Santosh Rathod       Electrician    9.2    NaN
# 7    8  09-03-2026    Saurabh Jadhav        Civil Exam    NaN    NaN
# 8    9  10-03-2026      Suraj jadhav           D pharm    8.3   54.0
# 9   10  11-03-2026     Kishor Jadhav    12 th pass out    2.7   25.0
# 10  11  12-03-2026      Divya Jadhav  Electonics & CSE    NaN   81.0
# 11  12  13-03-2026  Vaishnavi Chavan             CSE-B    5.9   81.0
# 12  13  14-03-2026      Rohini Agose           BA & MA    4.5   81.0
# ...

# %%
df.dtypes
# Out:
# SR          int64
# Date          str
# Nmes          str
# Trades        str
# Hours     float64
# Marks     float64
# dtype: object

# %%
type(df.Date[0])
# Out:
# str
