# %% [markdown]
# ## Pandas GroupBy () :

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\ajayr\\Downloads\\customers-100.csv")
df
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company            City    Country  \
# 0                   Rasmussen Group    East Leonard      Chile
# 1                       Vega-Gentry    East Leonard      Chile
# 2                     Murillo-Perry    East Leonard      Chile
# 3   Dominguez, Mcmillan and Donovan    East Leonard      Chile
# 4          Martin, Lang and Andrade  West Priscilla      Chile
# ...

# %%
gr1 = df.groupby(by= 'Company')
gr1

# %%
gr1.groups
# Out:
# {'Acosta, Petersen and Morrow': [30], 'Adkins-Salinas': [32], 'Anderson Ltd': [39], 'Beck-Hendrix': [9], 'Blankenship-Arias': [80], 'Brennan, Acosta and Ramos': [47], 'Brennan, Camacho and Tapia': [60], 'Browning-Simon': [8], 'Byrd Inc': [53], 'Byrd-Campbell': [90], 'Caldwell Group': [62], 'Carey LLC': [95], 'Carpenter-Cook': [13], 'Carter-Hancock': [14], 'Carter-Strickland': [88], 'Chang, Aguirre and Leblanc': [75], 'Christian, Winters and Ellis': [52], 'Church-Banks': [65], 'Coffey, Lamb and Johnson': [81], 'Combs, Waller and Durham': [79], 'Conway-Mcbride': [71], 'Costa PLC': [56], 'Cross PLC': [43], 'Decker-Mcknight': [89], 'Dominguez, Mcmillan and Donovan': [3], 'Donaldson-Dougherty': [67], 'Fitzgerald-Harrell': [98], 'Fitzpatrick-Lawrence': [82], 'Garcia-Jimenez': [83], 'Giles Ltd': [25], 'Glover and Sons': [37], 'Graham-Francis': [12], 'Greer and Sons': [22], 'Guzman-Brown': [74], 'Henderson Inc': [66], 'Herrera Group': [33], 'Herrera, Shepherd and Underwood': [44], 'Hinton, C
# ...

# %%
df.groupby(['Country' ,'Company']).groups
# Out:
# {('Albania', 'Tucker LLC'): RangeIndex(start=24, stop=25, step=1),
#  ('Algeria', 'May, Goodwin and Martin'): RangeIndex(start=51, stop=52, step=1),
#  ('Bahamas',
#   'Waters, Chase and Aguilar'): RangeIndex(start=34, stop=35, step=1),
#  ('Belarus',
#   'Hobbs, Garrett and Sanford'): RangeIndex(start=49, stop=50, step=1),
#  ('Belarus', 'Simmons Group'): RangeIndex(start=26, stop=27, step=1),
#  ('Belize',
#   'Palmer, Barnes and Houston'): RangeIndex(start=35, stop=36, step=1),
#  ('Benin', 'Vaughn, Watts and Leach'): RangeIndex(start=87, stop=88, step=1),
#  ('Bolivia', 'Perkins-Trevino'): RangeIndex(start=42, stop=43, step=1),
#  ('Bosnia and Herzegovina',
#   'Steele Group'): RangeIndex(start=5, stop=6, step=1),
#  ('Bulgaria', 'Cross PLC'): RangeIndex(start=43, stop=44, step=1),
#  ('Bulgaria',
#   'Sanford, Davenport and Giles'): RangeIndex(start=7, stop=8, step=1),
#  ('Burkina Faso', 'Kaufman and Sons'): RangeIndex(start=41, stop=42, step=1),
# ...

# %%
for Country, df_1 in gr1:
    print(Country)
    print(df_1)
# Out:
# Acosta, Petersen and Morrow
#     Index      Customer Id First Name Last Name                      Company  \
# 30     31  64DCcDFaB9DFd4e       Jack      Tate  Acosta, Petersen and Morrow
#
#            City   Country             Phone 1            Phone 2  \
# 30  West Samuel  Zimbabwe  965-108-4406x20714  046.906.1442x6784
#
#                          Email Subscription Date  \
# 30  gfigueroa@boone-zavala.com        15-09-2021
#
#                            Website
# 30  http://www.hawkins-ramsey.com/
# Adkins-Salinas
#     Index      Customer Id First Name Last Name         Company  \
# 32     33  7Ce381e4Afa4ba9    Gabriel     Mejia  Adkins-Salinas
#
#              City        Country     Phone 1             Phone 2  \
# 32  Port Annatown  Liechtenstein  4077245425  646.044.0696x66800
#
#                      Email Subscription Date                     Website
# 32  coleolson@jennings.net        24-04-2021  https://patel-hanson.info/
# Anderson Ltd
# ...

# %%
list(gr1)
# Out:
# [('Acosta, Petersen and Morrow',
#       Index      Customer Id First Name Last Name                      Company  \
#   30     31  64DCcDFaB9DFd4e       Jack      Tate  Acosta, Petersen and Morrow
#
#              City   Country             Phone 1            Phone 2  \
#   30  West Samuel  Zimbabwe  965-108-4406x20714  046.906.1442x6784
#
#                            Email Subscription Date  \
#   30  gfigueroa@boone-zavala.com        15-09-2021
#
#                              Website
#   30  http://www.hawkins-ramsey.com/  ),
#  ('Adkins-Salinas',
#       Index      Customer Id First Name Last Name         Company  \
#   32     33  7Ce381e4Afa4ba9    Gabriel     Mejia  Adkins-Salinas
#
#                City        Country     Phone 1             Phone 2  \
#   32  Port Annatown  Liechtenstein  4077245425  646.044.0696x66800
#
#                        Email Subscription Date                     Website
# ...

# %%
dict(list(gr1))
# Out:
# {'Acosta, Petersen and Morrow':     Index      Customer Id First Name Last Name                      Company  \
#  30     31  64DCcDFaB9DFd4e       Jack      Tate  Acosta, Petersen and Morrow
#
#             City   Country             Phone 1            Phone 2  \
#  30  West Samuel  Zimbabwe  965-108-4406x20714  046.906.1442x6784
#
#                           Email Subscription Date  \
#  30  gfigueroa@boone-zavala.com        15-09-2021
#
#                             Website
#  30  http://www.hawkins-ramsey.com/  ,
#  'Adkins-Salinas':     Index      Customer Id First Name Last Name         Company  \
#  32     33  7Ce381e4Afa4ba9    Gabriel     Mejia  Adkins-Salinas
#
#               City        Country     Phone 1             Phone 2  \
#  32  Port Annatown  Liechtenstein  4077245425  646.044.0696x66800
#
#                       Email Subscription Date                     Website
#  32  coleolson@jennings.net        24-04-2021  https://patel-hanson.info/  ,
# ...

# %%
gr3=df.groupby('Country').get_group('Chile')
gr3
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# 6       7  EA4d384DfDbBf77     Darren      Peck
# 8       9  C2dE4dEEc489ae0     Sheryl    Meyers
# 88     89  efeb73245CDf1fF     Vernon      Kane
# 90     91  5ef6d3eefdD43bE       Nina    Chavez
# 91     92  98b3aeDcC3B9FF3      Shane     Foley
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company            City Country  \
# 0                   Rasmussen Group    East Leonard   Chile
# 1                       Vega-Gentry    East Leonard   Chile
# ...

# %%
gr3=df.groupby('City').get_group('East Leonard')
gr3
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 5       6  2d08FB17EE273F4      Aimee     Downs
# 8       9  C2dE4dEEc489ae0     Sheryl    Meyers
# 91     92  98b3aeDcC3B9FF3      Shane     Foley
# 92     93  aAb6AFc7AfD0fF3     Collin     Ayers
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company          City                 Country  \
# 0                   Rasmussen Group  East Leonard                   Chile
# 1                       Vega-Gentry  East Leonard                   Chile
# 2                     Murillo-Perry  East Leonard                   Chile
# ...

# %%
df = pd.read_csv("C:\\Users\\ajayr\\Downloads\\archive (2)\\Income.csv")
df
# Out:
#     ID   Income   Age
# 0    1  10000.0  22.0
# 1    2  13000.0  30.0
# 2    3   5000.0  19.0
# 3    4      NaN  20.0
# 4    5   4300.0   NaN
# 5    6      NaN  33.0
# 6    7  20000.0  51.0
# 7    8  43000.0  28.0
# 8    9  48000.0  45.0
# 9   10  29000.0  44.0
# 10  11      NaN  31.0
# 11  12  32000.0  23.0
# 12  13   9000.0  12.0
# 13  14  11000.0  56.0
# 14  15   7000.0   NaN
# 15  16      NaN  32.0
# 16  17  61000.0  45.0
# 17  18  18000.0  52.0
# 18  19  43000.0  32.0
# 19  20  30000.0  45.0
# 20  21  70000.0  78.0
# 21  22  12000.0  43.0
# 22  23      NaN  56.0
# 23  24  23000.0   NaN
# 24  25  16000.0  37.0
# 25  26  17000.0  49.0
# 26  27      NaN  62.0
# 27  28      NaN  57.0
# 28  29  35000.0  51.0
# 29  30      NaN  33.0
# 30  31  47000.0  54.0

# %%
gr7 = df.groupby(by= 'Income')
gr7

# %%
gr7.sum()
# Out:
#          ID   Age
# Income
# 4300.0    5   0.0
# 5000.0    3  19.0
# 7000.0   15   0.0
# 9000.0   13  12.0
# 10000.0   1  22.0
# 11000.0  14  56.0
# 12000.0  22  43.0
# 13000.0   2  30.0
# 16000.0  25  37.0
# 17000.0  26  49.0
# 18000.0  18  52.0
# 20000.0   7  51.0
# 23000.0  24   0.0
# 29000.0  10  44.0
# 30000.0  20  45.0
# 32000.0  12  23.0
# 35000.0  29  51.0
# 43000.0  27  60.0
# 47000.0  31  54.0
# 48000.0   9  45.0
# 61000.0  17  45.0
# 70000.0  21  78.0

# %%
gr7.mean()
# Out:
#            ID   Age
# Income
# 4300.0    5.0   NaN
# 5000.0    3.0  19.0
# 7000.0   15.0   NaN
# 9000.0   13.0  12.0
# 10000.0   1.0  22.0
# 11000.0  14.0  56.0
# 12000.0  22.0  43.0
# 13000.0   2.0  30.0
# 16000.0  25.0  37.0
# 17000.0  26.0  49.0
# 18000.0  18.0  52.0
# 20000.0   7.0  51.0
# 23000.0  24.0   NaN
# 29000.0  10.0  44.0
# 30000.0  20.0  45.0
# 32000.0  12.0  23.0
# 35000.0  29.0  51.0
# 43000.0  13.5  30.0
# 47000.0  31.0  54.0
# 48000.0   9.0  45.0
# 61000.0  17.0  45.0
# 70000.0  21.0  78.0

# %%
gr7.agg(['sum', 'max', 'mean'])
# Out:
#          ID             Age
#         sum max  mean   sum   max  mean
# Income
# 4300.0    5   5   5.0   0.0   NaN   NaN
# 5000.0    3   3   3.0  19.0  19.0  19.0
# 7000.0   15  15  15.0   0.0   NaN   NaN
# 9000.0   13  13  13.0  12.0  12.0  12.0
# 10000.0   1   1   1.0  22.0  22.0  22.0
# 11000.0  14  14  14.0  56.0  56.0  56.0
# 12000.0  22  22  22.0  43.0  43.0  43.0
# 13000.0   2   2   2.0  30.0  30.0  30.0
# 16000.0  25  25  25.0  37.0  37.0  37.0
# 17000.0  26  26  26.0  49.0  49.0  49.0
# 18000.0  18  18  18.0  52.0  52.0  52.0
# 20000.0   7   7   7.0  51.0  51.0  51.0
# 23000.0  24  24  24.0   0.0   NaN   NaN
# 29000.0  10  10  10.0  44.0  44.0  44.0
# 30000.0  20  20  20.0  45.0  45.0  45.0
# 32000.0  12  12  12.0  23.0  23.0  23.0
# 35000.0  29  29  29.0  51.0  51.0  51.0
# 43000.0  27  19  13.5  60.0  32.0  30.0
# 47000.0  31  31  31.0  54.0  54.0  54.0
# 48000.0   9   9   9.0  45.0  45.0  45.0
# 61000.0  17  17  17.0  45.0  45.0  45.0
# ...
